# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt 
import pandas as pd 
import matplotlib.image as mpimg

# %%
df=pd.read_csv(r'C:\Users\saurabh\Documents\Desktop\Data Science projects\Data For Projects\States in India with Latitude and Longitude.csv')
df['States']=df['States'].str.replace(r"\(.*\)","").str.rstrip()
df.set_index('States',inplace=True)
df
# Out:
#                          Latitude  Longitude
# States
# Andaman And Nicobar     11.667026  92.735983
# Andhra Pradesh          14.750429  78.570026
# Arunachal Pradesh       27.100399  93.616601
# Assam                   26.749981  94.216667
# Bihar                   25.785414  87.479973
# Chandigarh              30.719997  76.780006
# Chhattisgarh            22.090420  82.159987
# Dadra And Nagar Haveli  20.266578  73.016618
# Delhi                   28.669993  77.230004
# Goa                     15.491997  73.818001
# Haryana                 28.450006  77.019991
# Himachal Pradesh        31.100025  77.166597
# Jammu And Kashmir       34.299959  74.466658
# Jharkhand               23.800393  86.419986
# Karnataka               12.570381  76.919997
# Kerala                   8.900373  76.569993
# Lakshadweep             10.562573  72.636867
# Madhya Pradesh          21.300391  76.130019
# Maharashtra             19.250232  73.160175
# Manipur                 24.799971  93.950017
# Meghalaya               25.570492  91.880014
# Mizoram                 23.710399  92.720015
# Nagaland                25.666998  94.116570
# Orissa                  19.820430  85.900017
# Puducherry              11.934994  79.830000
# Punjab                  31.519974  75.980003
# Rajasthan               26.449999  74.639981
# Sikkim                  27.333330  88.616647
# Tamil Nadu              12.920386  79.150042
# Tripura                 23.835404  91.279999
# Uttar Pradesh           27.599981  78.050006
# Uttaranchal             30.320409  78.050006
# West Bengal             22.580390  88.329947

# %%
state=pd.read_csv('https://api.covid19india.org/csv/latest/state_wise.csv')
state=state[['State','Confirmed']]
state.set_index('State',inplace=True)
state
# Out:
#                                           Confirmed
# State
# Total                                       3993412
# Maharashtra                                  843844
# Tamil Nadu                                   451827
# Andhra Pradesh                               476506
# Karnataka                                    379486
# Delhi                                        185220
# Uttar Pradesh                                253175
# West Bengal                                  174659
# Bihar                                        144134
# Telangana                                    135884
# Gujarat                                      101695
# Assam                                        118334
# Rajasthan                                     86965
# Odisha                                       116678
# Haryana                                       71983
# Madhya Pradesh                                70244
# Kerala                                        82105
# Punjab                                        60013
# Jammu and Kashmir                             40990
# Jharkhand                                     46480
# Chhattisgarh                                  39723
# Uttarakhand                                   22180
# Goa                                           19935
# Tripura                                       13833
# Puducherry                                    16172
# Manipur                                        6699
# Himachal Pradesh                               6615
# Nagaland                                       4107
# Arunachal Pradesh                              4574
# Andaman and Nicobar Islands                    3223
# Ladakh                                         2840
# Chandigarh                                     5268
# Dadra and Nagar Haveli and Daman and Diu       2510
# Meghalaya                                      2733
# Sikkim                                         1738
# Mizoram                                        1040
# State Unassigned                                  0
# Lakshadweep                                       0

# %%
State_Loc=pd.merge(state,df,how='inner',left_index=True,right_index=True)
State_Loc
# Out:
#                    Confirmed   Latitude  Longitude
# Maharashtra           843844  19.250232  73.160175
# Tamil Nadu            451827  12.920386  79.150042
# Andhra Pradesh        476506  14.750429  78.570026
# Karnataka             379486  12.570381  76.919997
# Delhi                 185220  28.669993  77.230004
# Uttar Pradesh         253175  27.599981  78.050006
# West Bengal           174659  22.580390  88.329947
# Bihar                 144134  25.785414  87.479973
# Assam                 118334  26.749981  94.216667
# Rajasthan              86965  26.449999  74.639981
# Haryana                71983  28.450006  77.019991
# Madhya Pradesh         70244  21.300391  76.130019
# Kerala                 82105   8.900373  76.569993
# Punjab                 60013  31.519974  75.980003
# Jharkhand              46480  23.800393  86.419986
# Chhattisgarh           39723  22.090420  82.159987
# Goa                    19935  15.491997  73.818001
# Tripura                13833  23.835404  91.279999
# Puducherry             16172  11.934994  79.830000
# Manipur                 6699  24.799971  93.950017
# Himachal Pradesh        6615  31.100025  77.166597
# Nagaland                4107  25.666998  94.116570
# Arunachal Pradesh       4574  27.100399  93.616601
# Chandigarh              5268  30.719997  76.780006
# Meghalaya               2733  25.570492  91.880014
# Sikkim                  1738  27.333330  88.616647
# Mizoram                 1040  23.710399  92.720015
# Lakshadweep                0  10.562573  72.636867

# %%
img=mpimg.imread(r'C:\Users\saurabh\Documents\Desktop\Data Science projects\Data For Projects\map[50.186,109.863,6.359,37.405].png')
plt.imshow(img,extent=[50.186,109.863,6.359,37.405],aspect=True)
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 250
plt.scatter(State_Loc.Longitude,State_Loc.Latitude,s=State_Loc.Confirmed/3000,alpha=0.25,edgecolor='red')
plt.savefig('testfig')

# %%
import pandas as pd
import mplleaflet
import ipywidgets
# import geopandas

import warnings
warnings.filterwarnings('ignore')
fig1,ax1 = plt.subplots(figsize=(12,9))
ax1.scatter(State_Loc.Longitude,State_Loc.Latitude,s=State_Loc.Confirmed/3000,alpha=0.25,edgecolor='red')
mplleaflet.display(fig=fig1)
# Out:
# <iframe src="data:text/html;base64,..." width="100%" height="540"></iframe>
