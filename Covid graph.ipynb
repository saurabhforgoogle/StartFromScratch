# %%
import pandas as pd 
time_covid=pd.read_csv('https://api.covid19india.org/csv/latest/case_time_series.csv')
time_covid
# Out:
#              Date  Daily Confirmed  Total Confirmed  Daily Recovered  \
# 0     30 January                 1                1                0
# 1     31 January                 0                1                0
# 2    01 February                 0                1                0
# 3    02 February                 1                2                0
# 4    03 February                 1                3                0
# ..            ...              ...              ...              ...
# 196    13 August             64141          2459626            54776
# 197    14 August             65610          2525236            56920
# 198    15 August             63986          2589222            53116
# 199    16 August             58096          2647318            57404
# 200    17 August             54298          2701616            58172
#
#      Total Recovered  Daily Deceased  Total Deceased
# 0                  0               0               0
# ...

# %%
time_covid['Active Cases']=time_covid['Total Confirmed']-time_covid['Total Recovered']-time_covid['Total Deceased']

# %%
from matplotlib import pyplot as plt 
Days=[i for i in range(len(time_covid))]
plt.style.use('seaborn-colorblind')
labels=['Active','Recovered','Deceased']
plt.stackplot(Days,time_covid['Active Cases']/1000,time_covid['Total Recovered']/1000,time_covid['Total Deceased']/1000,labels=labels,edgecolor='Black')
plt.title('Stack Plot-COVID India')
plt.xlabel('Days since Breakout',fontsize=14)
plt.ylabel('Number of Patients(in Thousands)',fontsize=14)
plt.legend(loc='upper left')
plt.show()

# %%
df=pd.read_csv('http://data.un.org/_Docs/SYB/CSV/SYB62_314_201904_Internet%20Usage.csv', encoding='ISO-8859-1',skiprows=1)
df.rename(columns={'Unnamed: 1':'Country'},inplace=True)
df=df[['Country',	'Year','Value']]
df=df[(df['Country']=='India') |(df['Country']=='Zimbambwe')]

# %%
df
# Out:
#     Country  Year  Value
# 777   India  2000    0.5
# 778   India  2005    2.4
# 779   India  2010    7.5
# 780   India  2014   21.0
# 781   India  2015   26.0
# 782   India  2016   29.5
# 783   India  2017   34.5
